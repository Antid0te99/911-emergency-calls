# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]

# %%
plt.plot(x,y, linestyle="--",label="Dashed Lines")   
plt.title("Test")
plt.xlabel("Age")
plt.ylabel("Height")
plt.legend()
plt.figure(figsize=(8,4))

# %%
names = ["A", "B", "C", "D"]
marks = [70, 85, 90, 60]

# %%
plt.bar(names,marks,label="Marksheet")
plt.xlabel("Student Names")
plt.ylabel("Marks")
plt.legend()

# %%
a=np.random.randn(1000)
a
# Out:
# array([-2.32515876e-03,  1.65472341e+00, -1.01220900e+00, -1.74436578e+00,
#         7.52638677e-01, -4.81803721e-01, -1.88473267e+00,  5.54651794e-01,
#         1.91723861e+00,  1.48512450e-01,  9.09118681e-01, -5.60077801e-01,
#         1.62421631e-01, -2.00626447e+00, -5.26385815e-01,  5.34091591e-01,
#        -6.61672299e-01,  5.41408812e-01,  7.29285996e-01,  2.92646289e-01,
#         1.37061354e+00, -7.62363169e-01,  2.12496132e-01, -3.59209439e-01,
#         1.18093864e-01,  1.57075262e+00,  4.49436845e-01,  9.62033677e-01,
#         7.53635257e-01, -5.08957184e-01,  3.74013007e-01,  1.70626632e+00,
#        -1.27147806e+00,  1.53073946e+00, -1.59170485e-01, -1.10684773e+00,
#        -9.29331770e-01,  1.46854933e-02, -3.96188073e-01,  6.32673282e-01,
#         1.07550314e+00, -8.16586451e-02, -5.99973048e-01, -1.47389596e+00,
#         7.99016833e-01, -4.18350629e-01, -7.11399861e-01,  3.97632540e-01,
# ...

# %%
plt.hist(a,bins=30)
# Out:
# (array([  1.,   0.,   3.,   1.,   4.,   6.,   9.,  18.,  36.,  36.,  48.,
#          74.,  99., 100.,  76.,  94.,  94.,  70.,  74.,  57.,  36.,  27.,
#          17.,   7.,   8.,   1.,   2.,   1.,   0.,   1.]),
#  array([-3.70594278, -3.45548398, -3.20502519, -2.95456639, -2.70410759,
#         -2.45364879, -2.20318999, -1.95273119, -1.70227239, -1.45181359,
#         -1.20135479, -0.95089599, -0.70043719, -0.44997839, -0.1995196 ,
#          0.0509392 ,  0.301398  ,  0.5518568 ,  0.8023156 ,  1.0527744 ,
#          1.3032332 ,  1.553692  ,  1.8041508 ,  2.0546096 ,  2.3050684 ,
#          2.5555272 ,  2.80598599,  3.05644479,  3.30690359,  3.55736239,
#          3.80782119]),
#  <BarContainer object of 30 artists>)

# %%
np.random.random(2)
# Out:
# array([0.53469813, 0.50621312])

# %%
np.random.uniform(5,10,5)
# Out:
# array([9.17755108, 7.78433243, 7.41688866, 7.02792166, 9.41827521])

# %%
df= pd.read_csv("scatter plot3.csv")

# %%
df.head()
# Out:
#    date  month  year   items   sale  profit  gender
# 0    25      3  2025  laptop  55000    5000    male
# 1    25      3  2025  laptop  55000    5000  female
# 2    25      3  2025  laptop  55000    5000    male
# 3    25      3  2025  laptop  55000    5000  female
# 4    25      3  2024  laptop  55000    5000    male

# %%
colours= df['gender'].map({'male':'blue','female':'red'})
plt.scatter(df['sale'],df['year'],c=colours)
plt.xlabel("Sales in units")
plt.ylabel("year")
plt.title("Sales vs Year")
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(8,4))
sns.boxplot(x=df['sale'],y=df['year'],pall)
# plt.scatter(df['sale'],df['year'],c=colours)
# Out:
# <Axes: xlabel='sale', ylabel='year'>
